# %%
import pandas as pd
import numpy as np
import glob

file_path = '*.xlsx'

files = glob.glob(file_path)
data = [
    [(sheet, pd.ExcelFile(file).parse(sheet)) 
     for sheet in pd.ExcelFile(file).sheet_names
    ] 
    for file in files
]

# %%
class IJ:
    def __init__ (self, data):
        self.data = dict(data)
        self.sheet_names, self.sheets = zip(*data)
        self.selected = 0
        
    def __iter__ (self):
        return iter(self.sheet_names)

    def select(self, sheet):
        for i in range(len(self.sheet_names)):
            if (self.sheet_names[i] == sheet):
                self.selected = i
                return
        raise Exception("No sheet by the name " + sheet + " sheet names are: ", self.sheet_names)
        
    def selecti(self, sheet):
        if (sheet >= len(self.sheet_names)):
            raise Exception("Index ", sheet, " out of range for size ", len(self.sheet_names))
        else:
            self.selected = sheet
            
    def select_next(self, i=1):
        self.selected = (self.selected + i) % len(self.sheet_names)
    
    def geti(self, indexes, i=None):
        return self.get(i).iloc[:, indexes]
        
    def gett(self, tags, i=None):
        return self.get(i)[tags]
        
    def get(self, i=None):
        return self.sheets[self.selected if i is None else i]

data2 = [IJ(d) for d in data]
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[131], line 41
#      39 ar2 = (list(sample2.get().columns))
#      40 if ar1 != ar2:
# ---> 41     raise Exception(ar1, ar2)
#
# Exception: (['Rbr IJ', 'Naziv izborne jedinice', 'Rbr.županije', 'Županija', 'Oznaka Gr/Op/Dr', 'Grad/općina/država', 'Rbr BM', 'Naziv BM', 'Lokacija BM', 'Adresa BM', 'Ukupno birača', 'Glasovalo birača', 'Glasovalo birača (po listićima)', 'Važeći listići', 'Nevažeći listići', 'AUTOHTONA - HRVATSKA STRANKA PRAVA - DRAŽEN KELEMINEC - A - HSP - Dražen Keleminec', 'TEOFIL KOŽUL', 'BORIS TAKAČ', 'ANTONIJO ZIDAR', 'ALOJZ HRŽENJAK', 'JADRANKA BIŠČANIĆ', 'ZDENKA BEBEK', 'RAJKO RADAČIĆ', 'VATROSLAVA BUDIMIR', 'ZVEZDANA POSTRUŽIN', 'DRAGUTIN BELOŠEVIĆ', 'VIŠNJA ZIEGELMEYER', 'GORAN POSTRUŽIN', 'MILE PAULIĆ', 'NADA LAZAREVIĆ', 'FOKUS, REPUBLIKA', 'DAMIR VANĐELIĆ', 'MARTINA KOLAR BILLEGE', 'VALENTINA PAVLOVIĆ VINOGRADAC', 'SUZANA SKOKO', 'MELITA BESTVINA', 'JASNA MATASIĆ', 'MILIVOJ MANDIĆ', 'DOMINIK KRAMARIĆ', 'VESELJKO RAJIČ', 'MLADEN LASIĆ', 'ANTONIO PRIŠĆAN', 'MARTINA MLINAC', 'ROBERT CAVOR', 'IVAN ŠKEGRO', 'ODLUČNOST I PRAVEDNOST - OIP', 'KAROLINA VIDOVIĆ KRIŠTO', 'DINO SAČARIĆ', 'TOMISLAV ANTE ZRNC', 'PETAR PETROVSKI', 'JOSIP TOMIČIĆ', 'HRVOJE LEKO', 'DARINKA MILJANA BARRUETO JAMAN', 'IVAN GLAVURDIĆ', 'IVANA ŠIKIĆ', 'DRAGAN KORUGA', 'SLAVEN RUPČIĆ', 'KRUNO POLJANČIĆ', 'DANIJELA CVITANOVIĆ', 'DAVOR KRNJAK', 'STRANKA IVANA PERNARA', 'LEONARDO LAMON', 'DUBRAVKA DRAGUN', 'LEO ALAGIĆ', 'DIJANA DELIĆ', 'ZDENKO RINČIĆ', 'MIRA KRIVOŠIJA', 'ANA RADOŠ', 'KARMELA FIŠER', 'MARKO KLIŠANIĆ', 'NEVENKA BORJAN', 'JAN ŠEREŠ', 'MARKO PETROVIĆ', 'HUBERT LOOS', 'DAVOR PERNAR', 'AGRARNA STRANKA - POKRET ZA HRVATSKU POLJOPRIVREDU, AKCIJA ZA PROMJENE', 'ROBERT HADŽIĆ', 'ŽELJKO ILIČIĆ', 'ŽELIMIRA VRABEC', 'MARIO ZACCARIA', 'ALBERT MARINCULIĆ', 'MIA CRNČIĆ', 'ŽELJKO POKASIĆ', 'LADA KRALJEVIĆ', 'MATE BULJAN', 'INES VRBAN', 'MLADEN DUJMOVIĆ', 'ANTONIA HOHNJEC', 'LJUBICA PAVRLIŠAK MARINCULIĆ', 'DENIS CVITKOVIĆ', 'DOMOVINSKI POKRET - DP, PRAVO I PRAVDA, BLOK ZA HRVATSKU - BLOK, AGRAMERI - NEZAVISNA LISTA', 'MISLAV KOLAKUŠIĆ', 'ZLATKO HASANBEGOVIĆ', 'ZVONIMIR LOVRIĆ', 'MARIJA VERONKICA CVJETKOVIĆ', 'MISLAV BARIŠIĆ', 'STJEPAN STANIĆ', 'MARIJANA PEHER', 'DALIBOR BOŽAN', 'ANA LEDERER', 'VLADIMIRA IVANKOVIĆ BRADIĆ', 'ANDREJA ŠEGO TURKOVIĆ', 'PERO IVANČIĆ', 'DORIS PERKOVIĆ', 'DRAŽAN DIZDAR', 'HRVATSKA DEMOKRATSKA ZAJEDNICA - HDZ, HRVATSKA SOCIJALNO - LIBERALNA STRANKA - HSLS, HRVATSKA DEMOKRŠĆANSKA STRANKA - HDS, HRVATSKA NARODNA STRANKA - LIBERALNI DEMOKRATI - HNS, HRVATSKA STRANKA UMIROVLJENIKA - HSU', 'ANDREJ PLENKOVIĆ', 'ŽELJKO REINER', 'NINA OBULJEN KORŽINEK', 'KREŠIMIR AČKAR', 'DARKO KLASIĆ', 'MARKO MILIĆ', 'LJUBICA LUKAČIĆ', 'ALEMKA MARKOTIĆ', 'MATO ČIČAK', 'MAKSIMILIJAN ŠIMRAK', 'MARIO ŽUPAN', 'TUGOMIR MAJDAK', 'IVICA MIŠKULIN', 'JOSIP LUCIĆ', 'HRVATSKA STRANKA PRAVA - HSP, HRVATSKO BILO, HRVATSKA DEMOKRATSKA SELJAČKA STRANKA - HDSS', 'STEFAN NOVAK', 'DAMIR KATULIĆ', 'STJEPAN PALČIĆ', 'MATE BEKAVAC', 'IVICA GAŠPAR', 'IVAN PALČIĆ', 'MAJA JUKIĆ', 'DANKO IŠTVANEK', 'ROBERT BODRUŽIĆ', 'IVANA VRSELJA', 'KARLO BLAGAJ', 'MIRJANA HEGEDUŠ', 'IVAN JURIŠIĆ', 'LJILJANA GLAD', 'JAVNO DOBRO', 'DINKA PAVELIĆ', 'MARKO MILIN', 'HRVOJE ČUPIĆ', 'LJILJANA MIHALJEVIĆ', 'ZORAN GRANCARIĆ', 'DAVORKA KATARINA CINDRIĆ', 'RENATA SKOVRON', 'NATAŠA JURLIN', 'DAMIR PIJAŽA-MIKELIĆ', 'MILOŠ ILIĆ', 'GALINA POPOVIĆ', 'NINO REBRONJA', 'IVA TADIĆ', 'LJUBICA ĐANKOVIĆ', 'MOST, HRVATSKI SUVERENISTI, HRVATSKA KONZERVATIVNA STRANKA - HKS, NEZAVISNA LISTA MLADIH - NLM', 'MARIJA SELAK RASPUDIĆ', 'IVAN BEKAVAC', 'GLORIA TKALČIĆ', 'BRANIMIR PERVAN', 'NADA FINDERLE', 'JOSIP PERIŠA', 'IRIS VERONIKA CETINA', 'KREŠIMIR ROTIM', 'TINA BULIĆ', 'LOVRO MILAKOVIĆ', 'VALENTINA DOROTIĆ', 'ANTONIO KULIŠ', 'MARIJA ZUBEC', 'DAMIR SLOJŠEK', 'MOŽEMO! - POLITIČKA PLATFORMA', 'SANDRA BENČIĆ', 'IVANA KEKIN', 'DAMIR BAKIĆ', 'TEODOR CELAKOSKI', 'MARTA KIŠ', 'MARIJA BRAJDIĆ VUKOVIĆ', 'LUKA KEREČIN', 'TOMISLAV DOMES', 'SUZANA DOBRIĆ', 'TONKO BOGOVAC', 'MARIJA KRNIĆ', 'LUKA KAMENEČKI', 'MATKO DUJMOVIĆ', 'JAN KRUHAK', 'POKRET ZA MODERNU HRVATSKU', 'SONJA VIDOŠEVIĆ LJUBIĆ', 'DAMIR MIHELIĆ', 'ELLA DELAČ', 'IVAN PURGAR', 'TENA ŠAMEC ...
